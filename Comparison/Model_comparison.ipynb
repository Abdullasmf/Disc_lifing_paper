# %%
import torch
from pathlib import Path
from typing import Any, Dict, List, Optional, Tuple, Union
import torch
import os
current_dir =  Path(
    os.path.dirname(os.path.abspath(__file__))
    if "__file__" in globals()
    else os.getcwd()
)

# %%
repo_root = current_dir.parent
print(f"Repository root: {repo_root}")

model_paths = sorted(
    str(p)
    for p in repo_root.rglob("*.pt")
    if "Trained_models" in p.parts
)

print(f"Found {len(model_paths)} model files")
# Out:
# Repository root: c:\Users\abfat\Desktop\Disc_lifing_paper
# Found 22 model files:

# %%
# Out:
# 'c:\\Users\\abfat\\Desktop\\Disc_lifing_paper\\Uniform\\Edge\\ArGEnT_self_att_noSDF\\Trained_models\\argent_self_nosdf_s_177b264d.pt'
